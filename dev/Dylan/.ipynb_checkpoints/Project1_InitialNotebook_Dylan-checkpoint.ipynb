# %% [markdown]
# Notebook to combine and bin data for the NHL from 2014-2019

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# Study data files
data1 = "nhl odds 2014-15.csv"
data2 = "nhl odds 2015-16.csv"
data3 = "nhl odds 2016-17.csv"
data4 = "nhl odds 2017-18.csv"
data5 = "nhl odds 2018-19.csv"

# Read the mouse data and the study results
data1 = pd.read_csv(data1)
data2 = pd.read_csv(data2)
data3 = pd.read_csv(data3)
data4 = pd.read_csv(data4)
data5 = pd.read_csv(data5)

# %%
#put the frames of the different seasons into a list
frames = [data1, data2, data3, data4, data5]

#stack the frames into a single set for analysis
df = pd.concat(frames)
df.head()
# Out:
#    Date  Rot VH          Team  1st  2nd  3rd  Final  Open  Close  Puck Line  \
# 0  1008    1  V      Montreal    1    1    2      4  -105   -105        1.5
# 1  1008    2  H       Toronto    2    0    1      3  -115   -115       -1.5
# 2  1008    3  V  Philadelphia    0    0    1      1   165    165        1.5
# 3  1008    4  H        Boston    1    0    1      2  -195   -185       -1.5
# 4  1008    5  V       SanJose    1    3    0      4   101    130        1.5
#
#    Unnamed: 11  Open OU  Unnamed: 13  Close OU  Unnamed: 15
# 0       -305.0      5.5          106       5.5          110
# 1        250.0      5.5         -126       5.5         -130
# 2       -180.0      5.5          123       5.5          115
# 3        155.0      5.5         -143       5.5         -135
# 4       -240.0      5.5          127       5.0         -136

# %%
p_dif = []

for i in range(1, df.shape[0], 2):
        home_dif = df['Final'].iloc[i] - df['Final'].iloc[i-1]
        away_dif = df['Final'].iloc[i-1] - df['Final'].iloc[i]
        p_dif.append(away_dif)
        p_dif.append(home_dif)
        
df['Point_Dif'] = p_dif
df.head()
# Out:
#    Date  Rot VH          Team  1st  2nd  3rd  Final  Open  Close  Puck Line  \
# 0  1008    1  V      Montreal    1    1    2      4  -105   -105        1.5
# 1  1008    2  H       Toronto    2    0    1      3  -115   -115       -1.5
# 2  1008    3  V  Philadelphia    0    0    1      1   165    165        1.5
# 3  1008    4  H        Boston    1    0    1      2  -195   -185       -1.5
# 4  1008    5  V       SanJose    1    3    0      4   101    130        1.5
#
#    Unnamed: 11  Open OU  Unnamed: 13  Close OU  Unnamed: 15  Point_Dif
# 0       -305.0      5.5          106       5.5          110          1
# 1        250.0      5.5         -126       5.5         -130         -1
# 2       -180.0      5.5          123       5.5          115         -1
# 3        155.0      5.5         -143       5.5         -135          1
# 4       -240.0      5.5          127       5.0         -136          4

# %%
ml_pays_result = []

for i in range(0, df.shape[0]):
    if df['Close'].iloc[i] < 0:
        result = -100/df['Close'].iloc[i]
        ml_pays_result.append(result)
    else:
        result = df['Close'].iloc[i]/100
        ml_pays_result.append(result)
        
df['ML_Pays'] = ml_pays_result
df.head()
# Out:
#    Date  Rot VH          Team  1st  2nd  3rd  Final  Open  Close  Puck Line  \
# 0  1008    1  V      Montreal    1    1    2      4  -105   -105        1.5
# 1  1008    2  H       Toronto    2    0    1      3  -115   -115       -1.5
# 2  1008    3  V  Philadelphia    0    0    1      1   165    165        1.5
# 3  1008    4  H        Boston    1    0    1      2  -195   -185       -1.5
# 4  1008    5  V       SanJose    1    3    0      4   101    130        1.5
#
#    Unnamed: 11  Open OU  Unnamed: 13  Close OU  Unnamed: 15  Point_Dif  \
# 0       -305.0      5.5          106       5.5          110          1
# 1        250.0      5.5         -126       5.5         -130         -1
# 2       -180.0      5.5          123       5.5          115         -1
# 3        155.0      5.5         -143       5.5         -135          1
# 4       -240.0      5.5          127       5.0         -136          4
#
#     ML_Pays
# 0  0.952381
# 1  0.869565
# 2  1.650000
# 3  0.540541
# 4  1.300000

# %%
pl_pays_result = []

for i in range(0, df.shape[0]):
    if df['Unnamed: 11'].iloc[i] < 0:
        result = -100/df['Unnamed: 11'].iloc[i]
        pl_pays_result.append(result)
    else:
        result = df['Unnamed: 11'].iloc[i]/100
        pl_pays_result.append(result)
        
df['PL_Pays'] = pl_pays_result
df.head()
# Out:
#    Date  Rot VH          Team  1st  2nd  3rd  Final  Open  Close  Puck Line  \
# 0  1008    1  V      Montreal    1    1    2      4  -105   -105        1.5
# 1  1008    2  H       Toronto    2    0    1      3  -115   -115       -1.5
# 2  1008    3  V  Philadelphia    0    0    1      1   165    165        1.5
# 3  1008    4  H        Boston    1    0    1      2  -195   -185       -1.5
# 4  1008    5  V       SanJose    1    3    0      4   101    130        1.5
#
#    Unnamed: 11  Open OU  Unnamed: 13  Close OU  Unnamed: 15  Point_Dif  \
# 0       -305.0      5.5          106       5.5          110          1
# 1        250.0      5.5         -126       5.5         -130         -1
# 2       -180.0      5.5          123       5.5          115         -1
# 3        155.0      5.5         -143       5.5         -135          1
# 4       -240.0      5.5          127       5.0         -136          4
#
#     ML_Pays   PL_Pays
# 0  0.952381  0.327869
# 1  0.869565  2.500000
# 2  1.650000  0.555556
# 3  0.540541  1.550000
# 4  1.300000  0.416667

# %%
ml_outcome = []

for i in range(0, df.shape[0]):
    if df['Point_Dif'].iloc[i] > 0:
        result = 100*df['ML_Pays'].iloc[i]
        ml_outcome.append(result)
    else:
        result = -100
        ml_outcome.append(result)
        
df['ML_Outcome'] = ml_outcome
df.head()
# Out:
#    Date  Rot VH          Team  1st  2nd  3rd  Final  Open  Close  Puck Line  \
# 0  1008    1  V      Montreal    1    1    2      4  -105   -105        1.5
# 1  1008    2  H       Toronto    2    0    1      3  -115   -115       -1.5
# 2  1008    3  V  Philadelphia    0    0    1      1   165    165        1.5
# 3  1008    4  H        Boston    1    0    1      2  -195   -185       -1.5
# 4  1008    5  V       SanJose    1    3    0      4   101    130        1.5
#
#    Unnamed: 11  Open OU  Unnamed: 13  Close OU  Unnamed: 15  Point_Dif  \
# 0       -305.0      5.5          106       5.5          110          1
# 1        250.0      5.5         -126       5.5         -130         -1
# 2       -180.0      5.5          123       5.5          115         -1
# 3        155.0      5.5         -143       5.5         -135          1
# 4       -240.0      5.5          127       5.0         -136          4
#
#     ML_Pays   PL_Pays  ML_Outcome
# 0  0.952381  0.327869   95.238095
# 1  0.869565  2.500000 -100.000000
# 2  1.650000  0.555556 -100.000000
# 3  0.540541  1.550000   54.054054
# 4  1.300000  0.416667  130.000000

# %%
pl_outcome = []

for i in range(0, df.shape[0]):
    if df['Point_Dif'].iloc[i] >= 2:
        result = 100*df['PL_Pays'].iloc[i]
        pl_outcome.append(result)
    elif (df['Point_Dif'].iloc[i] <= 1) & (df['Puck Line'].iloc[i] == -1.5):
        result = -100
        pl_outcome.append(result)
    elif (df['Point_Dif'].iloc[i] >= -1) & (df['Puck Line'].iloc[i] == 1.5):
        result = 100*df['PL_Pays'].iloc[i]
        pl_outcome.append(result)
    else:
        result = -100
        pl_outcome.append(result)
        
df['PL_Outcome'] = pl_outcome
df.head()
# Out:
#    Date  Rot VH          Team  1st  2nd  3rd  Final  Open  Close  ...  \
# 0  1008    1  V      Montreal    1    1    2      4  -105   -105  ...
# 1  1008    2  H       Toronto    2    0    1      3  -115   -115  ...
# 2  1008    3  V  Philadelphia    0    0    1      1   165    165  ...
# 3  1008    4  H        Boston    1    0    1      2  -195   -185  ...
# 4  1008    5  V       SanJose    1    3    0      4   101    130  ...
#
#    Unnamed: 11  Open OU  Unnamed: 13  Close OU  Unnamed: 15  Point_Dif  \
# 0       -305.0      5.5          106       5.5          110          1
# 1        250.0      5.5         -126       5.5         -130         -1
# 2       -180.0      5.5          123       5.5          115         -1
# 3        155.0      5.5         -143       5.5         -135          1
# 4       -240.0      5.5          127       5.0         -136          4
#
#     ML_Pays   PL_Pays  ML_Outcome  PL_Outcome
# 0  0.952381  0.327869   95.238095   32.786885
# 1  0.869565  2.500000 -100.000000 -100.000000
# 2  1.650000  0.555556 -100.000000   55.555556
# 3  0.540541  1.550000   54.054054 -100.000000
# 4  1.300000  0.416667  130.000000   41.666667
#
# [5 rows x 21 columns]

# %%
away_df = df[df['VH']=='V'].reset_index()
home_df = df[df['VH']=='H'].reset_index()

# %%
away_df.head()
# Out:
#    index  Date  Rot VH          Team  1st  2nd  3rd  Final  Open  ...  \
# 0      0  1008    1  V      Montreal    1    1    2      4  -105  ...
# 1      2  1008    3  V  Philadelphia    0    0    1      1   165  ...
# 2      4  1008    5  V       SanJose    1    3    0      4   101  ...
# 3      6  1008    7  V     Vancouver    1    2    1      4  -131  ...
# 4      8  1009   51  V      Montreal    0    0    1      2   115  ...
#
#    Unnamed: 11  Open OU  Unnamed: 13  Close OU  Unnamed: 15  Point_Dif  \
# 0       -305.0      5.5          106       5.5          110          1
# 1       -180.0      5.5          123       5.5          115         -1
# 2       -240.0      5.5          127       5.0         -136          4
# 3        230.0      5.5          123       5.0         -140          2
# 4       -245.0      5.5         -105       5.5          115          1
#
#     ML_Pays   PL_Pays  ML_Outcome  PL_Outcome
# 0  0.952381  0.327869   95.238095   32.786885
# 1  1.650000  0.555556 -100.000000   55.555556
# 2  1.300000  0.416667  130.000000   41.666667
# 3  0.793651  2.300000   79.365079  230.000000
# 4  1.250000  0.408163  125.000000   40.816327
#
# [5 rows x 22 columns]

# %%
home_df.head()
# Out:
#    index  Date  Rot VH        Team  1st  2nd  3rd  Final  Open  ...  \
# 0      1  1008    2  H     Toronto    2    0    1      3  -115  ...
# 1      3  1008    4  H      Boston    1    0    1      2  -195  ...
# 2      5  1008    6  H  LosAngeles    0    0    0      0  -121  ...
# 3      7  1008    8  H     Calgary    0    2    0      2   111  ...
# 4      9  1009   52  H  Washington    1    0    0      1  -135  ...
#
#    Unnamed: 11  Open OU  Unnamed: 13  Close OU  Unnamed: 15  Point_Dif  \
# 0        250.0      5.5         -126       5.5         -130         -1
# 1        155.0      5.5         -143       5.5         -135          1
# 2        200.0      5.5         -147       5.0          116         -4
# 3       -275.0      5.5         -143       5.0          120         -2
# 4        205.0      5.5         -115       5.5         -135         -1
#
#     ML_Pays   PL_Pays  ML_Outcome  PL_Outcome
# 0  0.869565  2.500000 -100.000000      -100.0
# 1  0.540541  1.550000   54.054054      -100.0
# 2  0.666667  2.000000 -100.000000      -100.0
# 3  1.060000  0.363636 -100.000000      -100.0
# 4  0.689655  2.050000 -100.000000      -100.0
#
# [5 rows x 22 columns]

# %%
home_df['ML_Outcome'].sum()
# Out:
# -29624.858063309508

# %%
home_df['PL_Outcome'].sum()
# Out:
# -25367.159463265205

# %%
away_df['ML_Outcome'].sum()
# Out:
# -16908.364093531975

# %%
away_df['PL_Outcome'].sum()
# Out:
# -27575.681092115858

# %%
fav_df = df[df['Puck Line']== -1.5].reset_index()
ud_df = df[df['Puck Line']== 1.5].reset_index()

# %%
fav_df['ML_Outcome'].sum()
# Out:
# -18217.1987315893

# %%
ud_df['ML_Outcome'].sum()
# Out:
# -28139.69225642102

# %%
fav_df['PL_Outcome'].sum()
# Out:
# -30249.87611154274

# %%
ud_df['PL_Outcome'].sum()
# Out:
# -22092.964443838315

# %%
x_values = df['Close']
y_values = df['Point_Dif']

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)

regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,3)) + "x + " + str(round(intercept,3))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-90, 9),fontsize=15,color="red")
plt.axhspan(-0.1, 0.1, -700, 700, color="black")
plt.axhspan(-12, 12, 0.528, 0.532, color="black")
plt.title('Closing Odds vs Point Differential')
plt.ylim(-11, 11)
plt.xlabel("Closing Odds")
plt.ylabel("Point Differential")
plt.show()

# %% [markdown]
# At -526, a team is expected to win by 1.5 goals, so puckline on the favorite is a better bet
# At +474, a team is expected to lose by 1.5 goals, so moneyline on the favorite is a better bet

# %%
print(df['Close'].min())
print(df['Close'].max())
# Out:
# -575
# 505

# %%
# Create favored team table
fav = []

# Iterate through the table and see which team had the lower number in closing (Favored to win)
for i in range(1,df.shape[0], 2):
    if (df['Close'].iloc[i] < df['Close'].iloc[i-1]):
        fav.append(df.iloc[i])
    else:
        fav.append(df.iloc[i-1])

# Create new table with just the favored team in it
favored_df = pd.DataFrame(fav)
favored_df

# Create row to see who won or loss by checking the point diferential was positive or negative.
def set_winner(row):
    if row['Point_Dif'] > 0:
        return 'Won'
    else:
        return 'Loss'

def set_pl_winner(row):
    if row['PL_Outcome'] > 0:
        return 'Won'
    else:
        return 'Loss'
# add the result column 
favored_df = favored_df.assign(ML_Result=favored_df.apply(set_winner, axis=1)) 
favored_df = favored_df.assign(PL_Result=favored_df.apply(set_pl_winner, axis=1))
favored_df.head()
# Out:
#    Date  Rot VH        Team  1st  2nd  3rd  Final  Open  Close  ...  \
# 1  1008    2  H     Toronto    2    0    1      3  -115   -115  ...
# 3  1008    4  H      Boston    1    0    1      2  -195   -185  ...
# 5  1008    6  H  LosAngeles    0    0    0      0  -121   -150  ...
# 6  1008    7  V   Vancouver    1    2    1      4  -131   -126  ...
# 9  1009   52  H  Washington    1    0    0      1  -135   -145  ...
#
#    Unnamed: 13  Close OU  Unnamed: 15  Point_Dif   ML_Pays  PL_Pays  \
# 1         -126       5.5         -130         -1  0.869565     2.50
# 3         -143       5.5         -135          1  0.540541     1.55
# 5         -147       5.0          116         -4  0.666667     2.00
# 6          123       5.0         -140          2  0.793651     2.30
# 9         -115       5.5         -135         -1  0.689655     2.05
#
#    ML_Outcome  PL_Outcome  ML_Result  PL_Result
# 1 -100.000000      -100.0       Loss       Loss
# 3   54.054054      -100.0        Won       Loss
# 5 -100.000000      -100.0       Loss       Loss
# 6   79.365079       230.0        Won        Won
# 9 -100.000000      -100.0       Loss       Loss
#
# [5 rows x 23 columns]

# %%
# Create the bins in which Data will be held
bins = [-600, -550.1, -500.1, -450.1, -400.1, -350.1, -300.1, -250.1, -200.1, -150.1, -100.1]

# Create the names for the four bins
group_names = ["-550+","-550 to -500", "-500 to -450", "-450 to -400", "-400 to -350", "-350 to -300", "-300 to -250", "-250 to -200", "-200 to -150", "-150 to PK"]

# %%
favored_df["Close Groups"] = pd.cut(favored_df["Close"], bins, labels=group_names, include_lowest=True)

# %%
output_data_file1 = "favored.csv"

ml_won = (favored_df['ML_Result'] == 'Won')
ml_loss = (favored_df['ML_Result'] == 'Loss')

pl_won = (favored_df['PL_Result'] == 'Won')
pl_loss = (favored_df['PL_Result'] == 'Loss')

home = (favored_df['VH'] == 'H')
away = (favored_df['VH'] == 'V')

fav_df = pd.DataFrame()

fav_df['Wins'] = favored_df[ml_won].groupby('Close Groups')['Team'].count()
fav_df['Losses'] = favored_df[ml_loss].groupby('Close Groups')['Team'].count()
fav_df['PL Wins'] = favored_df[pl_won].groupby('Close Groups')['Team'].count()
fav_df['PL Losses'] = favored_df[pl_loss].groupby('Close Groups')['Team'].count()
fav_df['Total'] = favored_df.groupby('Close Groups')['Team'].count()

fav_df['Win %'] = 100 * fav_df['Wins'] / fav_df['Total']
fav_df['Loss %'] = 100 * fav_df['Losses'] / fav_df['Total']
fav_df['PL Win %'] = 100 * fav_df['PL Wins'] / fav_df['Total']
fav_df['PL Loss %'] = 100 * fav_df['PL Losses'] / fav_df['Total']
fav_df['Mean ML Payout Odds'] = favored_df.groupby('Close Groups')['ML_Pays'].mean()
fav_df['Mean PL Payout Odds'] = favored_df.groupby('Close Groups')['PL_Pays'].mean()
fav_df['Expected ML Payouts'] = (fav_df['Win %'] * fav_df['Mean ML Payout Odds'])+(-1*fav_df['Loss %'])
fav_df['Expected PL Payouts'] = (fav_df['PL Win %'] * fav_df['Mean PL Payout Odds'])+(-1*fav_df['PL Loss %'])

fav_df['Wins'] = fav_df['Wins'].astype(int)
fav_df['Losses'] = fav_df['Losses'].astype(int)
fav_df['PL Wins'] = fav_df['PL Wins'].astype(int)
fav_df['PL Losses'] = fav_df['PL Losses'].astype(int)
fav_df['Total'] = fav_df['Total'].astype(int)

fav_df['Win %'] = round(fav_df['Win %'], 2)
fav_df['Loss %'] = round(fav_df['Loss %'], 2)
fav_df['PL Win %'] = round(fav_df['PL Win %'], 2)
fav_df['PL Loss %'] = round(fav_df['PL Loss %'], 2)
fav_df['Mean ML Payout Odds'] = round(fav_df['Mean ML Payout Odds'], 2)
fav_df['Mean PL Payout Odds'] = round(fav_df['Mean PL Payout Odds'], 2)
fav_df['Expected ML Payouts'] = round(fav_df['Expected ML Payouts'], 2)
fav_df['Expected PL Payouts'] = round(fav_df['Expected PL Payouts'], 2)

#fav_df.to_csv(output_data_file1)
fav_df
# Out:
#               Wins  Losses  PL Wins  PL Losses  Total   Win %  Loss %  \
# Close Groups
# -550+            1       0        1          0      1  100.00    0.00
# -550 to -500     3       1        3          1      4   75.00   25.00
# -500 to -450     2       0        2          0      2  100.00    0.00
# -450 to -400     9       0        5          4      9  100.00    0.00
# -400 to -350    16       7       12         11     23   69.57   30.43
# -350 to -300    49      20       31         38     69   71.01   28.99
# -300 to -250   132      58       92         98    190   69.47   30.53
# -250 to -200   424     194      250        368    618   68.61   31.39
# -200 to -150  1246     768      716       1298   2014   61.87   38.13
# -150 to PK    2036    1704     1195       2545   3740   54.44   45.56
#
#               PL Win %  PL Loss %  Mean ML Payout Odds  Mean PL Payout Odds  \
# Close Groups
# -550+           100.00       0.00                 0.17                 0.59
# -550 to -500     75.00      25.00                 0.19                 0.59
# -500 to -450    100.00       0.00                 0.22                 0.60
# -450 to -400     55.56      44.44                 0.24                 0.69
# -400 to -350     52.17      47.83                 0.27                 0.76
# -350 to -300     44.93      55.07                 0.31                 0.88
# -300 to -250     48.42      51.58                 0.37                 1.05
# -250 to -200     40.45      59.55                 0.45                 1.30
# -200 to -150     35.55      64.45                 0.59                 1.69
# -150 to PK       31.95      68.05                 0.78                 2.14
#
#               Expected ML Payouts  Expected PL Payouts
# Close Groups
# -550+                       17.39                58.82
# -550 to -500               -10.91                19.19
# -500 to -450                21.51                59.82
# -450 to -400                23.68                -6.28
# -400 to -350               -11.77                -7.94
# -350 to -300                -7.18               -15.36
# -300 to -250                -5.16                -0.70
# -250 to -200                -0.38                -6.78
# -200 to -150                -1.85                -4.28
# -150 to PK                  -2.96                 0.31

# %%
output_data_file1 = "favored.csv"

ml_won = (favored_df['ML_Result'] == 'Won')
ml_loss = (favored_df['ML_Result'] == 'Loss')

pl_won = (favored_df['PL_Result'] == 'Won')
pl_loss = (favored_df['PL_Result'] == 'Loss')

home = (favored_df['VH'] == 'H')
away = (favored_df['VH'] == 'V')

metrics_df = pd.DataFrame()

metrics_df['Home Wins'] = favored_df[ml_won & home].groupby('Close Groups')['Team'].count()
metrics_df['Home Losses'] = favored_df[ml_loss & home].groupby('Close Groups')['Team'].count()
metrics_df['Home PL Wins'] = favored_df[pl_won & home].groupby('Close Groups')['Team'].count()
metrics_df['Home PL Losses'] = favored_df[pl_loss & home].groupby('Close Groups')['Team'].count()
metrics_df['Home Total'] = favored_df[home].groupby('Close Groups')['Team'].count()

metrics_df['Home Win %'] = 100 * metrics_df['Home Wins'] / metrics_df['Home Total']
metrics_df['Home Loss %'] = 100 * metrics_df['Home Losses'] / metrics_df['Home Total']
metrics_df['Home PL Win %'] = 100 * metrics_df['Home PL Wins'] / metrics_df['Home Total']
metrics_df['Home PL Loss %'] = 100 * metrics_df['Home PL Losses'] / metrics_df['Home Total']
metrics_df['Home Mean ML Payout Odds'] = favored_df.groupby('Close Groups')['ML_Pays'].mean()
metrics_df['Home Mean PL Payout Odds'] = favored_df.groupby('Close Groups')['PL_Pays'].mean()
metrics_df['Home Expected ML Payouts'] = (metrics_df['Home Win %'] * metrics_df['Home Mean ML Payout Odds'])+(-1*metrics_df['Home Loss %'])
metrics_df['Home Expected PL Payouts'] = (metrics_df['Home PL Win %'] * metrics_df['Home Mean PL Payout Odds'])+(-1*metrics_df['Home PL Loss %'])

metrics_df['Home Wins'] = metrics_df['Home Wins'].astype(int)
metrics_df['Home Losses'] = metrics_df['Home Losses'].astype(int)
metrics_df['Home PL Wins'] = metrics_df['Home PL Wins'].astype(int)
metrics_df['Home PL Losses'] = metrics_df['Home PL Losses'].astype(int)
metrics_df['Home Total'] = metrics_df['Home Total'].astype(int)

metrics_df['Home Win %'] = round(metrics_df['Home Win %'], 2)
metrics_df['Home Loss %'] = round(metrics_df['Home Loss %'], 2)
metrics_df['Home PL Win %'] = round(metrics_df['Home PL Win %'], 2)
metrics_df['Home PL Loss %'] = round(metrics_df['Home PL Loss %'], 2)
metrics_df['Home Mean ML Payout Odds'] = round(metrics_df['Home Mean ML Payout Odds'], 2)
metrics_df['Home Mean PL Payout Odds'] = round(metrics_df['Home Mean PL Payout Odds'], 2)
metrics_df['Home Expected ML Payouts'] = round(metrics_df['Home Expected ML Payouts'], 2)
metrics_df['Home Expected PL Payouts'] = round(metrics_df['Home Expected PL Payouts'], 2)

#metrics_df.to_csv(output_data_file1)
metrics_df
# Out:
#               Home Wins  Home Losses  Home PL Wins  Home PL Losses  \
# Close Groups
# -550+                 1            0             1               0
# -550 to -500          3            1             3               1
# -500 to -450          2            0             2               0
# -450 to -400          9            0             5               4
# -400 to -350         14            7            11              10
# -350 to -300         44           18            28              34
# -300 to -250        128           52            89              91
# -250 to -200        386          171           229             328
# -200 to -150        971          628           567            1032
# -150 to PK         1277         1077           741            1613
#
#               Home Total  Home Win %  Home Loss %  Home PL Win %  \
# Close Groups
# -550+                  1      100.00         0.00         100.00
# -550 to -500           4       75.00        25.00          75.00
# -500 to -450           2      100.00         0.00         100.00
# -450 to -400           9      100.00         0.00          55.56
# -400 to -350          21       66.67        33.33          52.38
# -350 to -300          62       70.97        29.03          45.16
# -300 to -250         180       71.11        28.89          49.44
# -250 to -200         557       69.30        30.70          41.11
# -200 to -150        1599       60.73        39.27          35.46
# -150 to PK          2354       54.25        45.75          31.48
#
#               Home PL Loss %  Home Mean ML Payout Odds  \
# Close Groups
# -550+                   0.00                      0.17
# -550 to -500           25.00                      0.19
# -500 to -450            0.00                      0.22
# -450 to -400           44.44                      0.24
# -400 to -350           47.62                      0.27
# -350 to -300           54.84                      0.31
# -300 to -250           50.56                      0.37
# -250 to -200           58.89                      0.45
# -200 to -150           64.54                      0.59
# -150 to PK             68.52                      0.78
#
#               Home Mean PL Payout Odds  Home Expected ML Payouts  \
# Close Groups
# -550+                             0.59                     17.39
# -550 to -500                      0.59                    -10.91
# -500 to -450                      0.60                     21.51
# -450 to -400                      0.69                     23.68
# -400 to -350                      0.76                    -15.45
# -350 to -300                      0.88                     -7.24
# -300 to -250                      1.05                     -2.93
# -250 to -200                      1.30                      0.63
# -200 to -150                      1.69                     -3.66
# -150 to PK                        2.14                     -3.30
#
#               Home Expected PL Payouts
# Close Groups
# -550+                            58.82
# -550 to -500                     19.19
# -500 to -450                     59.82
# -450 to -400                     -6.28
# -400 to -350                     -7.58
# -350 to -300                    -14.92
# -300 to -250                      1.40
# -250 to -200                     -5.26
# -200 to -150                     -4.53
# -150 to PK                       -1.18

# %%
# Create favored team table
ud = []

# Iterate through the table and see which team had the lower number in closing (Favored to win)
for i in range(1,df.shape[0], 2):
    if (df['Close'].iloc[i] > df['Close'].iloc[i-1]):
        ud.append(df.iloc[i])
    else:
        ud.append(df.iloc[i-1])

# Create new table with just the favored team in it
dog_df = pd.DataFrame(ud)

# Create row to see who won or loss by checking the point diferential was positive or negative.
def set_winner(row):
    if row['Point_Dif'] > 0:
        return 'Won'
    else:
        return 'Loss'

def set_pl_winner(row):
    if row['PL_Outcome'] > 0:
        return 'Won'
    else:
        return 'Loss'
# add the result column 
dog_df = dog_df.assign(ML_Result=dog_df.apply(set_winner, axis=1)) 
dog_df = dog_df.assign(PL_Result=dog_df.apply(set_pl_winner, axis=1))
dog_df.head()
# Out:
#    Date  Rot VH          Team  1st  2nd  3rd  Final  Open  Close  ...  \
# 0  1008    1  V      Montreal    1    1    2      4  -105   -105  ...
# 2  1008    3  V  Philadelphia    0    0    1      1   165    165  ...
# 4  1008    5  V       SanJose    1    3    0      4   101    130  ...
# 7  1008    8  H       Calgary    0    2    0      2   111    106  ...
# 8  1009   51  V      Montreal    0    0    1      2   115    125  ...
#
#    Unnamed: 13  Close OU  Unnamed: 15  Point_Dif   ML_Pays   PL_Pays  \
# 0          106       5.5          110          1  0.952381  0.327869
# 2          123       5.5          115         -1  1.650000  0.555556
# 4          127       5.0         -136          4  1.300000  0.416667
# 7         -143       5.0          120         -2  1.060000  0.363636
# 8         -105       5.5          115          1  1.250000  0.408163
#
#    ML_Outcome  PL_Outcome  ML_Result  PL_Result
# 0   95.238095   32.786885        Won        Won
# 2 -100.000000   55.555556       Loss        Won
# 4  130.000000   41.666667        Won        Won
# 7 -100.000000 -100.000000       Loss       Loss
# 8  125.000000   40.816327        Won        Won
#
# [5 rows x 23 columns]

# %%
print(dog_df['Close'].max())
print(dog_df['Close'].min())
# Out:
# 505
# -110

# %%
# Create the bins in which Data will be held
bins = [-120, 149.9, 199.9, 249.9, 299.9, 349.9,399.9, 449.9, 499.9, 600]

# Create the names for the four bins
group_names = ["PK to +150","+150 to +200", "+200 to +250", "+250 to +300", "+300 to +350","+350 to +400", "+400 to +450", "+450 to +500", "+500 and up"]

# %%
dog_df["Close Groups"] = pd.cut(dog_df["Close"], bins, labels=group_names, include_lowest=True)

# %%
output_data_file2 = "dogs.csv"

ml_won = (dog_df['ML_Result'] == 'Won')
ml_loss = (dog_df['ML_Result'] == 'Loss')

pl_won = (dog_df['PL_Result'] == 'Won')
pl_loss = (dog_df['PL_Result'] == 'Loss')

home = (dog_df['VH'] == 'H')
away = (dog_df['VH'] == 'V')

metrics_df = pd.DataFrame()

metrics_df['Wins'] = dog_df[ml_won].groupby('Close Groups')['Team'].count()
metrics_df['Losses'] = dog_df[ml_loss].groupby('Close Groups')['Team'].count()
metrics_df['PL Wins'] = dog_df[pl_won].groupby('Close Groups')['Team'].count()
metrics_df['PL Losses'] = dog_df[pl_loss].groupby('Close Groups')['Team'].count()
metrics_df['Total'] = dog_df.groupby('Close Groups')['Team'].count()

metrics_df['Win %'] = 100 * metrics_df['Wins'] / metrics_df['Total']
metrics_df['Loss %'] = 100 * metrics_df['Losses'] / metrics_df['Total']
metrics_df['PL Win %'] = 100 * metrics_df['PL Wins'] / metrics_df['Total']
metrics_df['PL Loss %'] = 100 * metrics_df['PL Losses'] / metrics_df['Total']
metrics_df['Mean ML Payout Odds'] = dog_df.groupby('Close Groups')['ML_Pays'].mean()
metrics_df['Mean PL Payout Odds'] = dog_df.groupby('Close Groups')['PL_Pays'].mean()
metrics_df['Expected ML Payouts'] = (metrics_df['Win %'] * metrics_df['Mean ML Payout Odds'])+(-1*metrics_df['Loss %'])
metrics_df['Expected PL Payouts'] = (metrics_df['PL Win %'] * metrics_df['Mean PL Payout Odds'])+(-1*metrics_df['PL Loss %'])

metrics_df['Wins'] = metrics_df['Wins'].astype(int)
metrics_df['Losses'] = metrics_df['Losses'].astype(int)
metrics_df['PL Wins'] = metrics_df['PL Wins'].astype(int)
metrics_df['PL Losses'] = metrics_df['PL Losses'].astype(int)
metrics_df['Total'] = metrics_df['Total'].astype(int)

metrics_df['Win %'] = round(metrics_df['Win %'], 2)
metrics_df['Loss %'] = round(metrics_df['Loss %'], 2)
metrics_df['PL Win %'] = round(metrics_df['PL Win %'], 2)
metrics_df['PL Loss %'] = round(metrics_df['PL Loss %'], 2)
metrics_df['Mean ML Payout Odds'] = round(metrics_df['Mean ML Payout Odds'], 2)
metrics_df['Mean PL Payout Odds'] = round(metrics_df['Mean PL Payout Odds'], 2)
metrics_df['Expected ML Payouts'] = round(metrics_df['Expected ML Payouts'], 2)
metrics_df['Expected PL Payouts'] = round(metrics_df['Expected PL Payouts'], 2)

#metrics_df.to_csv(output_data_file2)
metrics_df
# Out:
#               Wins  Losses  PL Wins  PL Losses  Total  Win %  Loss %  \
# Close Groups
# PK to +150    2055    2604     3164       1495   4659  44.11   55.89
# +150 to +200   550    1002      946        606   1552  35.44   64.56
# +200 to +250   120     234      200        154    354  33.90   66.10
# +250 to +300    24      46       38         32     70  34.29   65.71
# +300 to +350     5      18       11         12     23  21.74   78.26
# +350 to +400     0       7        3          4      7   0.00  100.00
# +400 to +450     0       1        0          1      1   0.00  100.00
# +450 to +500     1       2        1          2      3  33.33   66.67
# +500 and up      0       1        0          1      1   0.00  100.00
#
#               PL Win %  PL Loss %  Mean ML Payout Odds  Mean PL Payout Odds  \
# Close Groups
# PK to +150       67.91      32.09                 1.17                 0.44
# +150 to +200     60.95      39.05                 1.68                 0.58
# +200 to +250     56.50      43.50                 2.16                 0.78
# +250 to +300     54.29      45.71                 2.66                 1.00
# +300 to +350     47.83      52.17                 3.16                 1.15
# +350 to +400     42.86      57.14                 3.70                 1.32
# +400 to +450      0.00     100.00                 4.25                 1.55
# +450 to +500     33.33      66.67                 4.57                 1.42
# +500 and up       0.00     100.00                 5.05                 1.45
#
#               Expected ML Payouts  Expected PL Payouts
# Close Groups
# PK to +150                  -4.43                -2.35
# +150 to +200                -5.20                -3.74
# +200 to +250                 7.23                 0.49
# +250 to +300                25.58                 8.72
# +300 to +350                -9.59                 2.67
# +350 to +400              -100.00                -0.76
# +400 to +450              -100.00              -100.00
# +450 to +500                85.56               -19.44
# +500 and up               -100.00              -100.00
